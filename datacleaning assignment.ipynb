# %%
import pandas as pd
df_salary=pd.read_csv("datacleaned.csv")
df_salary.head(15)
# Out:
#         Suburb              Address  Rooms Type      Price Method  SellerG  \
# 0   Abbotsford        68 Studley St    2.0    h        NaN     SS   Jellis
# 1   Abbotsford         85 Turner St    2.0    h  1480000.0      S   Biggin
# 2   Abbotsford      25 Bloomburg St    2.0    h  1035000.0      S   Biggin
# 3   Abbotsford   18/659 Victoria St    3.0    u        NaN     VB   Rounds
# 4   Abbotsford         5 Charles St    3.0    h  1465000.0     SP   Biggin
# 5   Abbotsford     40 Federation La    3.0    h   850000.0     PI   Biggin
# 6   Abbotsford          55a Park St    4.0    h  1600000.0     VB   Nelson
# 7   Abbotsford         16 Maugie St    4.0    h        NaN     SN   Nelson
# 8   Abbotsford         53 Turner St    2.0    h        NaN      S   Biggin
# 9   Abbotsford         99 Turner St    2.0    h        NaN      S  Collins
# 10  Abbotsford       129 Charles St    2.0    h   941000.0      S   Jellis
# ...

# %% [markdown]
# # 1.	Determine the no. of rows and no. of columns in the dataset.

# %%
df_salary.shape
# Out:
# (23678, 21)

# %% [markdown]
# # 2.	Display the datatypes of each column.

# %%
df_salary.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms            float64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %% [markdown]
# # 3.	Determine the row indexes of rows having all null values (i.e. empty rows).

# %%
df_salary.isnull().sum(axis=1
                      )
# Out:
# 0        3
# 1        2
# 2        0
# 3        3
# 4        0
#         ..
# 23673    2
# 23674    8
# 23675    4
# 23676    1
# 23677    2
# Length: 23678, dtype: int64

# %% [markdown]
# # 4.	Determine the total number of empty rows and their percentage in whole dataset and remove them

# %%
df_salary.isnull().any(axis = 1).sum()
# Out:
# 17482

# %%
df_salary.dropna(axis=0)
# Out:
#              Suburb          Address  Rooms Type      Price Method  \
# 2        Abbotsford  25 Bloomburg St    2.0    h  1035000.0      S
# 4        Abbotsford     5 Charles St    3.0    h  1465000.0     SP
# 6        Abbotsford      55a Park St    4.0    h  1600000.0     VB
# 11       Abbotsford     124 Yarra St    3.0    h  1876000.0      S
# 14       Abbotsford    98 Charles St    2.0    h  1636000.0      S
# ...             ...              ...    ...  ...        ...    ...
# 19845    Whittlesea    30 Sherwin St    3.0    h   601000.0      S
# 19846  Williamstown      75 Cecil St    3.0    h  1050000.0     VB
# 19847  Williamstown    2/29 Dover Rd    1.0    u   385000.0     SP
# 19849       Windsor  201/152 Peel St    2.0    u   560000.0     PI
# 19852    Yarraville  54 Pentland Pde    6.0    h  2450000.0     VB
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 2             Biggin  04-02-2016       2.5    3067.0  ...       1.0  0.0
# ...

# %% [markdown]
# # 5.	Determine the column names having missing values.

# %%
df_salary.isnull().sum()
# Out:
# Suburb             131
# Address            131
# Rooms              131
# Type               131
# Price             5282
# Method             131
# SellerG            131
# Date               131
# Distance           132
# Postcode           132
# Bedroom2          4612
# Bathroom          4615
# Car               4757
# Landsize          6268
# BuildingArea     13660
# YearBuilt        12138
# CouncilArea       8022
# Lattitude         4435
# Longtitude        4435
# Regionname         132
# Propertycount      132
# dtype: int64

# %% [markdown]
# # 6.	Determine the missing values and their percentage in each column.

# %%
df_salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23678 entries, 0 to 23677
# Data columns (total 21 columns):
# Suburb           23547 non-null object
# Address          23547 non-null object
# Rooms            23547 non-null float64
# Type             23547 non-null object
# Price            18396 non-null float64
# Method           23547 non-null object
# SellerG          23547 non-null object
# Date             23547 non-null object
# Distance         23546 non-null float64
# Postcode         23546 non-null float64
# Bedroom2         19066 non-null float64
# Bathroom         19063 non-null float64
# Car              18921 non-null float64
# Landsize         17410 non-null float64
# BuildingArea     10018 non-null float64
# YearBuilt        11540 non-null float64
# CouncilArea      15656 non-null object
# Lattitude        19243 non-null float64
# Longtitude       19243 non-null float64
# Regionname       23546 non-null object
# Propertycount    23546 non-null float64
# ...

# %%
df_salary.isnull().sum()
# Out:
# Suburb             131
# Address            131
# Rooms              131
# Type               131
# Price             5282
# Method             131
# SellerG            131
# Date               131
# Distance           132
# Postcode           132
# Bedroom2          4612
# Bathroom          4615
# Car               4757
# Landsize          6268
# BuildingArea     13660
# YearBuilt        12138
# CouncilArea       8022
# Lattitude         4435
# Longtitude        4435
# Regionname         132
# Propertycount      132
# dtype: int64

# %% [markdown]
# # 7.	Determine the row indexes having missing values.

# %%
for i in range(len(df_salary.index)) :
    print("Nan in row ", i , " : " ,  df_salary.iloc[i].isnull().sum())
# Out:
# Nan in row  0  :  3
# Nan in row  1  :  2
# Nan in row  2  :  0
# Nan in row  3  :  3
# Nan in row  4  :  0
# Nan in row  5  :  2
# Nan in row  6  :  0
# Nan in row  7  :  1
# Nan in row  8  :  2
# Nan in row  9  :  2
# Nan in row  10  :  2
# Nan in row  11  :  0
# Nan in row  12  :  1
# Nan in row  13  :  1
# Nan in row  14  :  0
# Nan in row  15  :  9
# Nan in row  16  :  9
# Nan in row  17  :  2
# Nan in row  18  :  0
# Nan in row  19  :  9
# Nan in row  20  :  1
# Nan in row  21  :  9
# Nan in row  22  :  9
# Nan in row  23  :  2
# Nan in row  24  :  0
# Nan in row  25  :  0
# Nan in row  26  :  7
# Nan in row  27  :  9
# Nan in row  28  :  2
# Nan in row  29  :  2
# Nan in row  30  :  0
# Nan in row  31  :  21
# Nan in row  32  :  1
# Nan in row  33  :  0
# Nan in row  34  :  9
# Nan in row  35  :  10
# Nan in row  36  :  0
# Nan in row  37  :  2
# Nan in row  38  :  0
# Nan in row  39  :  0
# Nan in row  40  :  1
# Nan in row  41  :  1
# Nan in row  42  :  1
# ...

# %% [markdown]
# # 8.	Determine the missing values and their percentage in each row.

# %%
for i in range(len(df_salary.index)) :
    print("Nan in row ", i , " : " ,  df_salary.iloc[i].isnull().sum())
# Out:
# Nan in row  0  :  3
# Nan in row  1  :  2
# Nan in row  2  :  0
# Nan in row  3  :  3
# Nan in row  4  :  0
# Nan in row  5  :  2
# Nan in row  6  :  0
# Nan in row  7  :  1
# Nan in row  8  :  2
# Nan in row  9  :  2
# Nan in row  10  :  2
# Nan in row  11  :  0
# Nan in row  12  :  1
# Nan in row  13  :  1
# Nan in row  14  :  0
# Nan in row  15  :  9
# Nan in row  16  :  9
# Nan in row  17  :  2
# Nan in row  18  :  0
# Nan in row  19  :  9
# Nan in row  20  :  1
# Nan in row  21  :  9
# Nan in row  22  :  9
# Nan in row  23  :  2
# Nan in row  24  :  0
# Nan in row  25  :  0
# Nan in row  26  :  7
# Nan in row  27  :  9
# Nan in row  28  :  2
# Nan in row  29  :  2
# Nan in row  30  :  0
# Nan in row  31  :  21
# Nan in row  32  :  1
# Nan in row  33  :  0
# Nan in row  34  :  9
# Nan in row  35  :  10
# Nan in row  36  :  0
# Nan in row  37  :  2
# Nan in row  38  :  0
# Nan in row  39  :  0
# Nan in row  40  :  1
# Nan in row  41  :  1
# Nan in row  42  :  1
# ...

# %%
df_salary.isnull().any(axis = 1).sum()
# Out:
# 17482

# %% [markdown]
# # 9.	Determine the column names having more than 30% missing values and remove them from the dataset.

# %%
pct_null = df_salary.isnull().sum() / len(df_salary)
missing_features = pct_null[pct_null > 0.30].index
df_salary.drop(missing_features, axis=1, inplace=True)

# %%
df_salary
# Out:
#              Suburb             Address  Rooms Type      Price Method  \
# 0        Abbotsford       68 Studley St    2.0    h        NaN     SS
# 1        Abbotsford        85 Turner St    2.0    h  1480000.0      S
# 2        Abbotsford     25 Bloomburg St    2.0    h  1035000.0      S
# 3        Abbotsford  18/659 Victoria St    3.0    u        NaN     VB
# 4        Abbotsford        5 Charles St    3.0    h  1465000.0     SP
# ...             ...                 ...    ...  ...        ...    ...
# 23673  Wyndham Vale     25 Clitheroe Dr    3.0    u        NaN     PN
# 23674  Wyndham Vale    19 Dalrymple Bvd    4.0    h        NaN      S
# 23675     Yallambie        17 Amaroo Wy    4.0    h  1100000.0      S
# 23676    Yarraville          6 Agnes St    4.0    h  1285000.0     SP
# 23677    Yarraville       33 Freeman St    4.0    h  1050000.0     VB
#
#              SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# ...

# %% [markdown]
# # 10.	Determine the number and percentage of rows having more than 5 missing values. If the percentage of such rows is less than 20% then remove all these rows.

# %% [markdown]
# already done

# %% [markdown]
# # 11.	Display the description of data and percentage of missing values still left column wise.

# %%
df_salary.isnull().sum()
# Out:
# Suburb            131
# Address           131
# Rooms             131
# Type              131
# Price            5282
# Method            131
# SellerG           131
# Date              131
# Distance          132
# Postcode          132
# Bedroom2         4612
# Bathroom         4615
# Car              4757
# Landsize         6268
# Lattitude        4435
# Longtitude       4435
# Regionname        132
# Propertycount     132
# dtype: int64

# %% [markdown]
# # Considering the 'Price' column as target variable which is to be predicted, how will you treat the missing values? Give a brief explanation and treat the missing values in 'Price' column

# %%
df_salary.head(30)
# Out:
#         Suburb              Address  Rooms Type      Price Method  \
# 0   Abbotsford        68 Studley St    2.0    h        NaN     SS
# 1   Abbotsford         85 Turner St    2.0    h  1480000.0      S
# 2   Abbotsford      25 Bloomburg St    2.0    h  1035000.0      S
# 3   Abbotsford   18/659 Victoria St    3.0    u        NaN     VB
# 4   Abbotsford         5 Charles St    3.0    h  1465000.0     SP
# 5   Abbotsford     40 Federation La    3.0    h   850000.0     PI
# 6   Abbotsford          55a Park St    4.0    h  1600000.0     VB
# 7   Abbotsford         16 Maugie St    4.0    h        NaN     SN
# 8   Abbotsford         53 Turner St    2.0    h        NaN      S
# 9   Abbotsford         99 Turner St    2.0    h        NaN      S
# 10  Abbotsford       129 Charles St    2.0    h   941000.0      S
# 11  Abbotsford         124 Yarra St    3.0    h  1876000.0      S
# 12  Abbotsford  121/56 Nicholson St    2.0    u        NaN     PI
# ...

# %% [raw]
# by looking at the price column its better to replace missing values with mean value

# %%
# Replace using median 
df2 = df_salary['Price'].mean()

# %%
df2
# Out:
# 1056697.4609154165

# %%
df_salary['Price'].fillna(df2, inplace=True)

# %%
df_salary.head()
# Out:
#        Suburb             Address  Rooms Type         Price Method SellerG  \
# 0  Abbotsford       68 Studley St    2.0    h  1.056697e+06     SS  Jellis
# 1  Abbotsford        85 Turner St    2.0    h  1.480000e+06      S  Biggin
# 2  Abbotsford     25 Bloomburg St    2.0    h  1.035000e+06      S  Biggin
# 3  Abbotsford  18/659 Victoria St    3.0    u  1.056697e+06     VB  Rounds
# 4  Abbotsford        5 Charles St    3.0    h  1.465000e+06     SP  Biggin
#
#          Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0  03-09-2016       2.5    3067.0       2.0       1.0  1.0     126.0
# 1  03-12-2016       2.5    3067.0       2.0       1.0  1.0     202.0
# 2  04-02-2016       2.5    3067.0       2.0       1.0  0.0     156.0
# 3  04-02-2016       2.5    3067.0       3.0       2.0  1.0       0.0
# 4  04-03-2017       2.5    3067.0       3.0       2.0  0.0     134.0
#
#    Lattitude  Longtitude             Regionname  Propertycount
# ...

# %%
df_salary.isnull().sum()
# Out:
# Suburb            131
# Address           131
# Rooms             131
# Type              131
# Price               0
# Method            131
# SellerG           131
# Date              131
# Distance          132
# Postcode          132
# Bedroom2         4612
# Bathroom         4615
# Car              4757
# Landsize         6268
# Lattitude        4435
# Longtitude       4435
# Regionname        132
# Propertycount     132
# dtype: int64

# %% [markdown]
# # 13.	Now check the percentage of missing values in each column again, if missing values exist, treat it with the most suitable method.

# %%
# Replace using mode
df3 = df_salary['Address'].mode()

# %%
df_salary['Address'].fillna(df2, inplace=True)

# %%
# Replace using mode 
df4 = df_salary['Rooms'].mode()

# %%
df_salary['Rooms'].fillna(df4, inplace=True)

# %%
# Replace using mode
df5 = df_salary['Type'].mode()
df_salary['Type'].fillna(df5, inplace=True)

# %%
# Replace using mode
df6 = df_salary['SellerG'].mode()
df_salary['SellerG'].fillna(df6, inplace=True)

# %%
# Replace using mode
df7 = df_salary['Date'].mode()
df_salary['Date'].fillna(df7, inplace=True)

# %%
# Replace using mode
df8 = df_salary['Distance'].mode()
df_salary['Distance'].fillna(df8, inplace=True)

# %%
# Replace using mode
df9 = df_salary['Postcode'].mode()
df_salary['Postcode'].fillna(df9, inplace=True)

# %%
# Replace using mode
df10 = df_salary['Bedroom2'].mode()
df_salary['Bedroom2'].fillna(df10, inplace=True)

# %%
# Replace using mode
df11 = df_salary['Bathroom'].mode()
df_salary['Bathroom'].fillna(df11, inplace=True)

# %%
# Replace using mode
df12 = df_salary['Car'].mode()
df_salary['Car'].fillna(df12, inplace=True)

# %%
# Replace using mode
df13 = df_salary['Landsize'].mode()
df_salary['Landsize'].fillna(df13, inplace=True)

# %%
# Replace using mode
df14 = df_salary['Lattitude'].mode()
df_salary['Lattitude'].fillna(df14, inplace=True)

# %%
# Replace using mode
df15 = df_salary['Longtitude'].mode()
df_salary['Longtitude'].fillna(df15, inplace=True)

# %%
# Replace using mode
df16 = df_salary['Regionname'].mode()
df_salary['Regionname'].fillna(df16, inplace=True)

# %%
# Replace using mode
df17 = df_salary['Propertycount'].mode()
df_salary['Propertycount'].fillna(df17, inplace=True)

# %%
df_salary.head(20)
# Out:
#         Suburb              Address  Rooms Type         Price Method  SellerG  \
# 0   Abbotsford        68 Studley St    2.0    h  1.056697e+06     SS   Jellis
# 1   Abbotsford         85 Turner St    2.0    h  1.480000e+06      S   Biggin
# 2   Abbotsford      25 Bloomburg St    2.0    h  1.035000e+06      S   Biggin
# 3   Abbotsford   18/659 Victoria St    3.0    u  1.056697e+06     VB   Rounds
# 4   Abbotsford         5 Charles St    3.0    h  1.465000e+06     SP   Biggin
# 5   Abbotsford     40 Federation La    3.0    h  8.500000e+05     PI   Biggin
# 6   Abbotsford          55a Park St    4.0    h  1.600000e+06     VB   Nelson
# 7   Abbotsford         16 Maugie St    4.0    h  1.056697e+06     SN   Nelson
# 8   Abbotsford         53 Turner St    2.0    h  1.056697e+06      S   Biggin
# 9   Abbotsford         99 Turner St    2.0    h  1.056697e+06      S  Collins
# 10  Abbotsford       129 Charles St    2.0    h  9.410000e+05      S   Jellis
# ...

# %% [markdown]
# df_salary.fillna(mode)

# %%
df_salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23678 entries, 0 to 23677
# Data columns (total 18 columns):
# Suburb           23547 non-null object
# Address          23678 non-null object
# Rooms            23547 non-null float64
# Type             23547 non-null object
# Price            23678 non-null float64
# Method           23547 non-null object
# SellerG          23547 non-null object
# Date             23547 non-null object
# Distance         23546 non-null float64
# Postcode         23546 non-null float64
# Bedroom2         19066 non-null float64
# Bathroom         19063 non-null float64
# Car              18921 non-null float64
# Landsize         17410 non-null float64
# Lattitude        19243 non-null float64
# Longtitude       19243 non-null float64
# Regionname       23546 non-null object
# Propertycount    23546 non-null float64
# dtypes: float64(11), object(7)
# memory usage: 3.3+ MB

# %%
df_salary.shape
# Out:
# (23678, 18)

# %% [markdown]
# 3 coulumns were deleted some wat ok but i did not delete null values in rows because around 17000 odd rows has missing values which is not viable option for further analysis
